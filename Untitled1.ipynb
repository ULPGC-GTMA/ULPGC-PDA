# %%
pwd
# Out:
# 'C:\\Users\\Usuario\\SW Repositories\\clases\\ULPGC-PDA'

# %%
from PIL import Image, ImageOps

# %%
file = 'images/chinche_L.png'
print(type(file))
print(id(file))

img  = Image.open(file)
print(type(img))
print(id(img))
# Out:
# <class 'str'>
# 2373092155808
# <class 'PIL.PngImagePlugin.PngImageFile'>
# 2373093412672

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=500x375>

# %%
ImageOps.invert(img)
# Out:
# <PIL.Image.Image image mode=L size=500x375>
