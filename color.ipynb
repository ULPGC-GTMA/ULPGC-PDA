# %%
import matplotlib.pyplot as plt

import colour
import colour.plotting as cplt

# %% [markdown]
# ## Colour checkers
#
# https://babelcolor.com/colorchecker.htm

# %%
# CCS: Chromaticity coordinates of the colour checkers.
print(type(colour.CCS_COLOURCHECKERS))
print(sorted(colour.CCS_COLOURCHECKERS))
# Out:
# <class 'colour.utilities.data_structures.CaseInsensitiveMapping'>
# ['BabelColor Average', 'ColorChecker 1976', 'ColorChecker 2005', 'ColorChecker24 - After November 2014', 'ColorChecker24 - Before November 2014', 'babel_average', 'cc2005', 'cca2014', 'ccb2014']

# %%
display(colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data)
cplt.plot_single_colour_checker('ColorChecker24 - After November 2014');
# Out:
# {'dark skin': array([ 0.4374836 ,  0.37852284,  0.09832436]),
#  'light skin': array([ 0.42224944,  0.37249369,  0.3362023 ]),
#  'blue sky': array([ 0.27614744,  0.29838157,  0.17855193]),
#  'foliage': array([ 0.37331613,  0.45116914,  0.13467927]),
#  'blue flower': array([ 0.30289052,  0.28628691,  0.2287176 ]),
#  'bluish green': array([ 0.28640483,  0.38971778,  0.41435547]),
#  'orange': array([ 0.52814772,  0.40533497,  0.31264162]),
#  'purplish blue': array([ 0.23238585,  0.21120372,  0.10910902]),
#  'moderate red': array([ 0.50444755,  0.32706475,  0.18899996]),
#  'purple': array([ 0.33347115,  0.2505523 ,  0.06276663]),
#  'yellow green': array([ 0.39889345,  0.50414915,  0.43317594]),
#  'orange yellow': array([ 0.493576  ,  0.4442832 ,  0.42933776]),
#  'blue': array([ 0.20522077,  0.16866548,  0.05596214]),
#  'green': array([ 0.32303796,  0.51041818,  0.22334376]),
#  'red': array([ 0.56287232,  0.33556281,  0.12780083]),
#  'yellow': array([ 0.46775935,  0.47602443,  0.59929768]),
#  'magenta': array([ 0.42131089,  0.26692462,  0.18951146]),
#  'cyan': array([ 0.20912872,  0.30265801,  0.18060991]),
#  'white 9.5 (.05 D)': array([ 0.34891449,  0.36421258,  0.88069032]),
#  'neutral 8 (.23 D)': array([ 0.34558386,  0.35988061,  0.58997097]),
#  'neutral 6.5 (.44 D)': array([ 0.34414983,  0.35918507,  0.36486521]),
#  'neutral 5 (.70 D)': array([ 0.34576922,  0.35909383,  0.19062288]),
#  'neutral 3.5 (1.05 D)': array([ 0.34264843,  0.35758352,  0.08817235]),
#  'black 2 (1.5 D)': array([ 0.34376747,  0.35605763,  0.03151319])}

# %%
# Comparación: checker proporcionado en segundo lugar en el interior
display(colour.CCS_COLOURCHECKERS['ColorChecker 1976'].data)
cplt.plot_multi_colour_checkers(['ColorChecker 1976', 'ColorChecker24 - After November 2014']);
# Out:
# {'dark skin': array([ 0.4002,  0.3504,  0.1005]),
#  'light skin': array([ 0.3773,  0.3446,  0.3582]),
#  'blue sky': array([ 0.247 ,  0.2514,  0.1933]),
#  'foliage': array([ 0.3372,  0.422 ,  0.1329]),
#  'blue flower': array([ 0.2651,  0.24  ,  0.2427]),
#  'bluish green': array([ 0.2608,  0.343 ,  0.4306]),
#  'orange': array([ 0.506 ,  0.407 ,  0.3005]),
#  'purplish blue': array([ 0.211,  0.175,  0.12 ]),
#  'moderate red': array([ 0.4533,  0.3058,  0.1977]),
#  'purple': array([ 0.2845,  0.202 ,  0.0656]),
#  'yellow green': array([ 0.38  ,  0.4887,  0.4429]),
#  'orange yellow': array([ 0.4729,  0.4375,  0.4306]),
#  'blue': array([ 0.1866,  0.1285,  0.0611]),
#  'green': array([ 0.3046,  0.4782,  0.2339]),
#  'red': array([ 0.5385,  0.3129,  0.12  ]),
#  'yellow': array([ 0.448 ,  0.4703,  0.591 ]),
#  'magenta': array([ 0.3635,  0.2325,  0.1977]),
#  'cyan': array([ 0.1958,  0.2519,  0.1977]),
#  'white 9.5 (.05 D)': array([ 0.3101,  0.3163,  0.9001]),
#  'neutral 8 (.23 D)': array([ 0.3101,  0.3163,  0.591 ]),
#  'neutral 6.5 (.44 D)': array([ 0.3101,  0.3163,  0.362 ]),
#  'neutral 5 (.70 D)': array([ 0.3101,  0.3163,  0.1977]),
#  'neutral 3.5 (1.05 D)': array([ 0.3101,  0.3163,  0.09  ]),
#  'black 2 (1.5 D)': array([ 0.3101,  0.3163,  0.0313])}

# %% [markdown]
# Representamos colores. ¿Es buena la representación?

# %%
white_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data['white 9.5 (.05 D)']

col = 'green'
col_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data[col]
col_XYZ = colour.xyY_to_XYZ(col_xyY)
col_sRGB = colour.XYZ_to_sRGB(col_XYZ)
print(col.title(), '\n xyY (cromacidad): ', col_xyY, '\tsRGB: ', col_sRGB)


cplt.plot_single_colour_swatch(
    cplt.ColourSwatch(col_sRGB, col.title()),
    text_kwargs={'size': 'x-large'});

white_XYZ = colour.xyY_to_XYZ(white_xyY)
white_sRGB = colour.XYZ_to_sRGB(white_XYZ)
cplt.plot_single_colour_swatch(
    cplt.ColourSwatch(white_sRGB, 'Blanco'),
    text_kwargs={'size': 'x-large'});
# Out:
# Green
#  xyY (cromacidad):  [ 0.32303796  0.51041818  0.22334376] 	sRGB:  [ 0.31022702  0.57033847  0.21900918]

# %% [markdown]
# ## Balance de blanco

# %%
white_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data['white 9.5 (.05 D)']

col = 'green'
col_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data[col]
col_XYZ = colour.xyY_to_XYZ(col_xyY)
col_sRGB = colour.XYZ_to_sRGB(col_XYZ, illuminant = white_xyY )
print(col.title(), '\n xyY (cromacidad): ', col_xyY, '\tsRGB: ', col_sRGB)


cplt.plot_single_colour_swatch(
    cplt.ColourSwatch(col_sRGB, col.title()),
    text_kwargs={'size': 'x-large'});

white_XYZ = colour.xyY_to_XYZ(white_xyY)
white_sRGB = colour.XYZ_to_sRGB(white_XYZ, illuminant = white_xyY)
cplt.plot_single_colour_swatch(
    cplt.ColourSwatch(white_sRGB, 'Blanco'),
    text_kwargs={'size': 'x-large'});
# Out:
# Green
#  xyY (cromacidad):  [ 0.32303796  0.51041818  0.22334376] 	sRGB:  [ 0.25172529  0.60855956  0.31146929]

# %% [markdown]
# ## Representación en diagrama de cromaticidad

# %%
cplt.plot_RGB_colourspaces_in_chromaticity_diagram_CIE1931(['sRGB'], plot_kwargs={'color': 'w', 'marker': None }, standalone = False)

x, y = colour.xyY_to_xy(white_xyY)
plt.plot(x, y, 'o-', color='white')

col = 'red'
col_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data[col]
x, y = colour.xyY_to_xy(col_xyY)
plt.plot(x, y, 'o-', color='red')


col = 'green'
col_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data[col]
x, y = colour.xyY_to_xy(col_xyY)
plt.plot(x, y, 'o-', color='green')

col = 'blue'
col_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data[col]
x, y = colour.xyY_to_xy(col_xyY)
plt.plot(x, y, 'o-', color='blue')

# Displaying the plot.
cplt.render(
    standalone=True,
    limits=(-0.1, 0.9, -0.1, 0.9),
    x_tighten=True,
    y_tighten=True);

# %% [markdown]
# ## Iluminantes

# %%
print(sorted(colour.CCS_ILLUMINANTS['CIE 1931 2 Degree Standard Observer'].keys()))
# Out:
# ['A', 'ACES', 'B', 'Blackmagic Wide Gamut', 'C', 'D50', 'D55', 'D60', 'D65', 'D75', 'DCI-P3', 'E', 'FL1', 'FL10', 'FL11', 'FL12', 'FL2', 'FL3', 'FL3.1', 'FL3.10', 'FL3.11', 'FL3.12', 'FL3.13', 'FL3.14', 'FL3.15', 'FL3.2', 'FL3.3', 'FL3.4', 'FL3.5', 'FL3.6', 'FL3.7', 'FL3.8', 'FL3.9', 'FL4', 'FL5', 'FL6', 'FL7', 'FL8', 'FL9', 'HP1', 'HP2', 'HP3', 'HP4', 'HP5', 'ICC D50', 'ID50', 'ID65', 'ISO 7589 Photoflood', 'ISO 7589 Photographic Daylight', 'ISO 7589 Sensitometric Daylight', 'ISO 7589 Sensitometric Photoflood', 'ISO 7589 Sensitometric Printer', 'ISO 7589 Sensitometric Studio Tungsten', 'ISO 7589 Studio Tungsten', 'LED-B1', 'LED-B2', 'LED-B3', 'LED-B4', 'LED-B5', 'LED-BH1', 'LED-RGB1', 'LED-V1', 'LED-V2']

# %%
cplt.temperature.plot_planckian_locus_in_chromaticity_diagram( ['A', 'B', 'C', 'D', 'E']);

# %% [markdown]
# Ahora hacemos el balance de blancos con un iluminante (D50)

# %%
illuminant_xyY = colour.CCS_ILLUMINANTS['CIE 1931 2 Degree Standard Observer']['D50']

col = 'green'
col_xyY = colour.CCS_COLOURCHECKERS['ColorChecker24 - After November 2014'].data[col]
col_XYZ = colour.xyY_to_XYZ(col_xyY)
col_sRGB = colour.XYZ_to_sRGB(col_XYZ, illuminant = illuminant_xyY )
print(col.title(), '\n xyY (cromacidad): ', col_xyY, '\tsRGB: ', col_sRGB)


cplt.plot_single_colour_swatch(
    cplt.ColourSwatch(col_sRGB, col.title()),
    text_kwargs={'size': 'x-large'});

white_XYZ = colour.xyY_to_XYZ(white_xyY)
white_sRGB = colour.XYZ_to_sRGB(white_XYZ, illuminant = illuminant_xyY)
cplt.plot_single_colour_swatch(
    cplt.ColourSwatch(white_sRGB, 'Blanco'),
    text_kwargs={'size': 'x-large'});
# Out:
# Green
#  xyY (cromacidad):  [ 0.32303796  0.51041818  0.22334376] 	sRGB:  [ 0.23314562  0.57550885  0.28181555]

# %%
CCT_D50 = 5000 * 1.4388 / 1.4380
xy = colour.temperature.CCT_to_xy_CIE_D(CCT_D50)

sd = colour.sd_CIE_illuminant_D_series(xy)  

cplt.plot_single_sd(sd);
